# %%
import pandas as pd
import numpy as np
from pymatgen.core import Composition
import re
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.model_selection import train_test_split
import math
from joblib import Parallel, delayed
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import LeaveOneOut
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import cross_val_score
from tqdm import tqdm
config = {
    "mathtext.fontset":'stix',
    "font.family":'serif',
    "font.serif": ['Arial'],
    "font.size": 24,
    'axes.unicode_minus': False 
}
plt.rcParams.update(config)
plt.rcParams['axes.unicode_minus'] = False  
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (8, 6),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.rcParams['figure.dpi'] = 400
plt.rcParams['axes.grid'] = False

# %%
def init_population(n,c):
    return np.array([[math.ceil(e) for e in pop] for pop in (np.random.rand(n,c)-0.5)]), np.zeros((2,c))-1

def single_point_crossover(population):
    r,c, n = population.shape[0], population.shape[1], np.random.randint(1,population.shape[1])         
    for i in range(0,r,2):                
        population[i], population[i+1] = np.append(population[i][0:n],population[i+1][n:c]),np.append(population[i+1][0:n],population[i][n:c])        
    return population

def flip_mutation(population):
    return population.max() - population

def random_selection(population):
    r = population.shape[0]
    new_population = population.copy()    
    for i in range(r):        
        new_population[i] = population[np.random.randint(0,r)]
    return new_population
def predictive_model(X,y,model):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,shuffle=True, random_state=42)
    mdl = model
    mdl.fit(X_train,y_train) 
    y_pred = mdl.predict(X_test)
    return r2_score(y_test, y_pred)
def get_fitness(data,feature_list,target,population,model):    
    fitness = []
    for i in range(population.shape[0]):    
        columns = [feature_list[j] for j in range(population.shape[1]) if population[i,j]==1]
        score = predictive_model(data[columns], data[target],model)
        fitness.append(score)                
    return fitness
def memorize(pop, memory):      
    return np.append(memory, pop.reshape(1,memory.shape[1]), axis=0)
def replace_duplicate(population, memory):    
    for i in range(population.shape[0]):         
        counter = 0                
        while any(np.all(memory == population[i], axis=1)) and (counter < 100): 
            population[i] = np.array([math.ceil(k) for k in (np.random.rand(population.shape[1])-0.5)])                    
            counter += 1                    
        memory = memorize(population[i], memory)   
    return population, memory

# %%
def ga(data, feature_list, target, n, max_iter,model):
    
    c = len(feature_list)
    
    population, memory = init_population(n,c)
    population, memory = replace_duplicate(population, memory)    
    
    fitness = get_fitness(data, feature_list, target, population,model)    
    
    optimal_value = max(fitness)
    optimal_solution = population[np.where(fitness==optimal_value)][0]    
    
    for i in range(max_iter): 
        start = time()
        population = random_selection(population)
        population = single_point_crossover(population)                        
        if np.random.rand() < 0.3:
            population = flip_mutation(population)   
        
        population, memory = replace_duplicate(population, memory)
                
        fitness = get_fitness(data, feature_list, target, population,model)
                
        if max(fitness) > optimal_value:
            optimal_value    = max(fitness)
            optimal_solution = population[np.where(fitness==optimal_value)][0]                               
        end = time()
        print(f"第 %d 次迭代T = %0.4f, optimize_value = %0.4f" % (i,end - start,optimal_value))
    return optimal_solution, optimal_value

# %%
small_data = pd.read_csv('/data/single_perovskite_oxide.csv')
small_data = small_data.drop(columns = 'Unnamed: 0').reset_index(drop=True)
small_data = small_data.drop(columns = 'composition').reset_index(drop=True)
small_data['composition'] = small_data['formula'].map(Composition)
y_eg_abo3 = small_data['target']

# %%
re_data = pd.read_csv('/data/all_features_df.csv')
ABO3_atomic_features = pd.read_csv('/data/small_atomic_features_new.csv').drop(columns = 'Unnamed: 0')
atomic_features = pd.read_csv('/data/ao_features.csv')

# %%
ABO3_atomic_features
# Out:
#     A_atomic_hfomo  A_atomic_hpomo  A_atomic_lfumo  A_atomic_lpumo
# 29  ...           0.41365  3.44       13.61805        35.1211             2.0
# 30  ...           0.41365  3.44       13.61805        35.1211             2.0
# 31  ...           0.41365  3.44       13.61805        35.1211             2.0
# 32  ...           0.41365  3.44       13.61805        35.1211             2.0
# 33  ...           0.41365  3.44       13.61805        35.1211             2.0
# 34  ...           0.41365  3.44       13.61805        35.1211             2.0
# 35  ...           0.41365  3.44       13.61805        35.1211             2.0
# 36  ...           0.41365  3.44       13.61805        35.1211             2.0
# 37  ...           0.41365  3.44       13.61805        35.1211             2.0
# 38  ...           0.41365  3.44       13.61805        35.1211             2.0
# 39  ...           0.41365  3.44       13.61805        35.1211             2.0
# 40  ...           0.41365  3.44       13.61805        35.1211             2.0
# 41  ...           0.41365  3.44       13.61805        35.1211             2.0
# 42  ...           0.41365  3.44       13.61805        35.1211             2.0
# 43  ...           0.41365  3.44       13.61805        35.1211             2.0
# 44  ...           0.41365  3.44       13.61805        35.1211             2.0
# 45  ...           0.41365  3.44       13.61805        35.1211             2.0
# 46  ...           0.41365  3.44       13.61805        35.1211             2.0
# 47  ...           0.41365  3.44       13.61805        35.1211             2.0
# 48  ...           0.41365  3.44       13.61805        35.1211             2.0
# 49  ...           0.41365  3.44       13.61805        35.1211             2.0
# 50  ...           0.41365  3.44       13.61805        35.1211             2.0
# 51  ...           0.41365  3.44       13.61805        35.1211             2.0
#
#     X_atomic_npval  X_atomic_nsval  X_atomic_nunf  X_atomic_nval  X_atomic_pol
# 0              4.0             2.0            2.0            6.0         0.802
# 1              4.0             2.0            2.0            6.0         0.802
# 2              4.0             2.0            2.0            6.0         0.802
# 3              4.0             2.0            2.0            6.0         0.802
# 4              4.0             2.0            2.0            6.0         0.802
# 5              4.0             2.0            2.0            6.0         0.802
# 6              4.0             2.0            2.0            6.0         0.802
# 7              4.0             2.0            2.0            6.0         0.802
# 8              4.0             2.0            2.0            6.0         0.802
# 9              4.0             2.0            2.0            6.0         0.802
# 10             4.0             2.0            2.0            6.0         0.802
# 11             4.0             2.0            2.0            6.0         0.802
# 12             4.0             2.0            2.0            6.0         0.802
# 13             4.0             2.0            2.0            6.0         0.802
# 14             4.0             2.0            2.0            6.0         0.802
# 15             4.0             2.0            2.0            6.0         0.802
# 16             4.0             2.0            2.0            6.0         0.802
# 17             4.0             2.0            2.0            6.0         0.802
# 18             4.0             2.0            2.0            6.0         0.802
# 19             4.0             2.0            2.0            6.0         0.802
# 20             4.0             2.0            2.0            6.0         0.802
# 21             4.0             2.0            2.0            6.0         0.802
# 22             4.0             2.0            2.0            6.0         0.802
# 23             4.0             2.0            2.0            6.0         0.802
# 24             4.0             2.0            2.0            6.0         0.802
# 25             4.0             2.0            2.0            6.0         0.802
# 26             4.0             2.0            2.0            6.0         0.802
# 27             4.0             2.0            2.0            6.0         0.802
# 28             4.0             2.0            2.0            6.0         0.802
# 29             4.0             2.0            2.0            6.0         0.802
# 30             4.0             2.0            2.0            6.0         0.802
# 31             4.0             2.0            2.0            6.0         0.802
# 32             4.0             2.0            2.0            6.0         0.802
# 33             4.0             2.0            2.0            6.0         0.802
# 34             4.0             2.0            2.0            6.0         0.802
# 35             4.0             2.0            2.0            6.0         0.802
# 36             4.0             2.0            2.0            6.0         0.802
# 37             4.0             2.0            2.0            6.0         0.802
# 38             4.0             2.0            2.0            6.0         0.802
# 39             4.0             2.0            2.0            6.0         0.802
# 40             4.0             2.0            2.0            6.0         0.802
# 41             4.0             2.0            2.0            6.0         0.802
# 42             4.0             2.0            2.0            6.0         0.802
# 43             4.0             2.0            2.0            6.0         0.802
# 44             4.0             2.0            2.0            6.0         0.802
# 45             4.0             2.0            2.0            6.0         0.802
# 46             4.0             2.0            2.0            6.0         0.802
# 47             4.0             2.0            2.0            6.0         0.802
# 48             4.0             2.0            2.0            6.0         0.802
# 49             4.0             2.0            2.0            6.0         0.802
# 50             4.0             2.0            2.0            6.0         0.802
# 51             4.0             2.0            2.0            6.0         0.802
#
# [52 rows x 114 columns]

# %%
atomic_labels = atomic_features.columns
select_atomic_labels = atomic_labels
atomic_features
# Out:
#        A_atomic_hfomo  A_atomic_hpomo  A_atomic_lfumo  A_atomic_lpumo  \
# 0           -4.210348       -2.165658       -2.165658       -2.165658
# 1           -4.210348       -2.165658       -2.165658       -2.165658
# 2           -4.210348       -2.165658       -2.165658       -2.165658
# 3           -4.210348       -2.165658       -2.165658       -2.165658
# 4           -4.210348       -2.165658       -2.165658       -2.165658
# ...               ...             ...             ...             ...
# 72843       -3.709160       -3.709160       -0.900650       -0.900650
# 72844       -3.709160       -3.709160       -0.900650       -0.900650
# 72845       -3.709160       -3.709160       -0.900650       -0.900650
# 72846       -3.709160       -3.709160       -0.900650       -0.900650
# 72847       -3.709160       -3.709160       -0.900650       -0.900650
#
#        A_atomic_ea  A_atomic_ip  A_atomic_ea_by_half_charged_homo  \
# 0        -0.299291     4.230849                          1.754248
# 1        -0.299291     4.230849                          1.754248
# 2        -0.299291     4.230849                          1.754248
# 3        -0.299291     4.230849                          1.754248
# 4        -0.299291     4.230849                          1.754248
# ...            ...          ...                               ...
# 72843     1.114753     5.960128                          1.136460
# 72844     1.114753     5.960128                          1.136460
# 72845     1.114753     5.960128                          1.136460
# 72846     1.114753     5.960128                          1.136460
# 72847     1.114753     5.960128                          1.136460
#
#        A_atomic_ip_by_half_charged_homo  A_atomic_r_s_neg_1  \
# 0                              6.900584             1.90799
# 1                              6.900584             1.90799
# 2                              6.900584             1.90799
# 3                              6.900584             1.90799
# 4                              6.900584             1.90799
# ...                                 ...                 ...
# 72843                          5.964720             2.16695
# 72844                          5.964720             2.16695
# 72845                          5.964720             2.16695
# 72846                          5.964720             2.16695
# 72847                          5.964720             2.16695
#
#        A_atomic_r_val_neg_1  ...  B_atomic_ie_1  B_atomic_ie_2  \
# 0                   0.81939  ...       6.766510      16.485700
# 1                   0.81939  ...       7.881010      17.084000
# 2                   0.81939  ...       7.902400      16.187700
# 3                   0.81939  ...       6.758850      14.000000
# 4                   0.81939  ...       7.343920      14.632200
# ...                     ...  ...            ...            ...
# 72843               2.26615  ...       5.925526      11.667650
# 72844               2.26615  ...       5.676880      13.749545
# 72845               2.26615  ...       6.322594      12.498752
# 72846               2.26615  ...       6.141961       0.000000
# 72847               2.26615  ...       5.672820      13.243565
#
#        B_atomic_ndunf  B_atomic_ndval  B_atomic_npunf  B_atomic_npval  \
# 0                 5.0             5.0             0.0             0.0
# 1                 3.0             7.0             0.0             0.0
# 2                 4.0             6.0             0.0             0.0
# 3                 6.0             4.0             0.0             0.0
# 4                 0.0            10.0             4.0             2.0
# ...               ...             ...             ...             ...
# 72843             8.7             1.3             0.0             0.0
# 72844             6.3             3.7             1.5             0.3
# 72845             6.3             0.7             1.2             0.6
# 72846             8.4             1.6             0.0             0.0
# 72847             6.3             0.7             1.5             0.3
#
#        B_atomic_nunf  B_atomic_nval  B_atomic_phi  B_atomic_pol
# 0                6.0            6.0         4.650        11.600
# 1                3.0            9.0         5.100         7.500
# 2                4.0            8.0         4.930         8.400
# 3                7.0            5.0         4.050        15.700
# 4                4.0           14.0         4.150         7.060
# ...              ...            ...           ...           ...
# 72843           17.8            4.0         3.366        25.100
# 72844           16.9            6.7         3.456        23.156
# 72845           16.6            4.0         3.636        22.379
# 72846           17.5            8.5         3.441        24.650
# 72847           16.9            3.7         3.486        22.760
#
# [72848 rows x 62 columns]

# %% [markdown]
# # EC

# %%
data = re_data[select_atomic_labels].copy(deep = True)
data
# Out:
#        A_atomic_hfomo  A_atomic_hpomo  A_atomic_lfumo  A_atomic_lpumo  \
# 0           -4.210348       -2.165658       -2.165658       -2.165658
# 1           -4.210348       -2.165658       -2.165658       -2.165658
# 2           -4.210348       -2.165658       -2.165658       -2.165658
# 3           -4.210348       -2.165658       -2.165658       -2.165658
# 4           -4.210348       -2.165658       -2.165658       -2.165658
# ...               ...             ...             ...             ...
# 35320       -3.709160       -3.709160       -0.900650       -0.900650
# 35321       -3.709160       -3.709160       -0.900650       -0.900650
# 35322       -3.709160       -3.709160       -0.900650       -0.900650
# 35323       -3.709160       -3.709160       -0.900650       -0.900650
# 35324       -3.709160       -3.709160       -0.900650       -0.900650
#
#        A_atomic_ea  A_atomic_ip  A_atomic_ea_by_half_charged_homo  \
# 0        -0.299291     4.230849                          1.754248
# 1        -0.299291     4.230849                          1.754248
# 2        -0.299291     4.230849                          1.754248
# 3        -0.299291     4.230849                          1.754248
# 4        -0.299291     4.230849                          1.754248
# ...            ...          ...                               ...
# 35320     1.114753     5.960128                          1.136460
# 35321     1.114753     5.960128                          1.136460
# 35322     1.114753     5.960128                          1.136460
# 35323     1.114753     5.960128                          1.136460
# 35324     1.114753     5.960128                          1.136460
#
#        A_atomic_ip_by_half_charged_homo  A_atomic_r_s_neg_1  \
# 0                              6.900584             1.90799
# 1                              6.900584             1.90799
# 2                              6.900584             1.90799
# 3                              6.900584             1.90799
# 4                              6.900584             1.90799
# ...                                 ...                 ...
# 35320                          5.964720             2.16695
# 35321                          5.964720             2.16695
# 35322                          5.964720             2.16695
# 35323                          5.964720             2.16695
# 35324                          5.964720             2.16695
#
#        A_atomic_r_val_neg_1  ...  B_atomic_ie_1  B_atomic_ie_2  \
# 0                   0.81939  ...       6.766510      16.485700
# 1                   0.81939  ...       7.902400      16.187700
# 2                   0.81939  ...       6.633900      13.100000
# 3                   0.81939  ...       7.899430      15.934610
# 4                   0.81939  ...       6.825070      15.000000
# ...                     ...  ...            ...            ...
# 35320               2.26615  ...       5.867260      11.525000
# 35321               2.26615  ...       6.673900      13.058342
# 35322               2.26615  ...       6.246919      12.375383
# 35323               2.26615  ...       5.924611      12.095000
# 35324               2.26615  ...       5.925526      11.667650
#
#        B_atomic_ndunf  B_atomic_ndval  B_atomic_npunf  B_atomic_npval  \
# 0                 5.0             5.0             0.0             0.0
# 1                 4.0             6.0             0.0             0.0
# 2                 8.0             2.0             0.0             0.0
# 3                 0.0            10.0             4.0             2.0
# 4                 8.0             2.0             0.0             0.0
# ...               ...             ...             ...             ...
# 35320             8.7             1.3             0.0             0.0
# 35321             6.3             0.7             0.0             0.0
# 35322             6.3             3.7             1.2             0.6
# 35323             8.7             1.3             0.0             0.0
# 35324             8.7             1.3             0.0             0.0
#
#        B_atomic_nunf  B_atomic_nval  B_atomic_phi  B_atomic_pol
# 0                6.0            6.0         4.650        11.600
# 1                4.0            8.0         4.930         8.400
# 2                8.0            4.0         3.450        17.900
# 3                4.0           14.0         4.550         5.840
# 4                8.0           18.0         3.600        16.200
# ...              ...            ...           ...           ...
# 35320           17.8            4.0         3.261        26.090
# 35321           15.4            3.4         3.741        22.400
# 35322           16.6            7.0         3.591        22.472
# 35323           17.8            8.2         3.306        25.580
# 35324           17.8            4.0         3.366        25.100
#
# [35325 rows x 62 columns]

# %%
from scipy.stats import spearmanr
def remove_collinear_features(x, y,threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model
        to generalize and improves the interpretability of the model.
        
    Inputs: 
        threshold: any features with correlations greater than this value are removed
    
    Output: 
        dataframe that contains only the non-highly-collinear features
    '''  
    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)
            
            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
#                 print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                x1 = x[col.values[0]]
                x2 = x[row.values[0]]
                corr1,p1 = spearmanr(x1, y)
                corr2,p2 = spearmanr(x2, y)
                if np.abs(corr1) < np.abs(corr2):
                    drop_cols.append(col.values[0])
                else:
                    drop_cols.append(row.values[0])
    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    x = x.drop(columns = drops)
    return x

# %%
X = data.copy(deep = True)
y = re_data['Eg']
X = remove_collinear_features(X,y,0.8)
fl = X.columns
X = data[fl]
X
# Out:
#        A_atomic_hpomo  A_atomic_lfumo  A_atomic_lpumo  A_atomic_ea  \
# 0           -2.165658       -2.165658       -2.165658    -0.299291
# 1           -2.165658       -2.165658       -2.165658    -0.299291
# 2           -2.165658       -2.165658       -2.165658    -0.299291
# 3           -2.165658       -2.165658       -2.165658    -0.299291
# 4           -2.165658       -2.165658       -2.165658    -0.299291
# ...               ...             ...             ...          ...
# 35320       -3.709160       -0.900650       -0.900650     1.114753
# 35321       -3.709160       -0.900650       -0.900650     1.114753
# 35322       -3.709160       -0.900650       -0.900650     1.114753
# 35323       -3.709160       -0.900650       -0.900650     1.114753
# 35324       -3.709160       -0.900650       -0.900650     1.114753
#
#        A_atomic_ip  A_atomic_r_val  A_atomic_r_s_1  A_atomic_r_d_1  \
# 0         4.230849         0.53737         0.00000             0.0
# 1         4.230849         0.53737         0.00000             0.0
# 2         4.230849         0.53737         0.00000             0.0
# 3         4.230849         0.53737         0.00000             0.0
# 4         4.230849         0.53737         0.00000             0.0
# ...            ...             ...             ...             ...
# 35320     5.960128         1.96785         1.83315             0.0
# 35321     5.960128         1.96785         1.83315             0.0
# 35322     5.960128         1.96785         1.83315             0.0
# 35323     5.960128         1.96785         1.83315             0.0
# 35324     5.960128         1.96785         1.83315             0.0
#
#        A_atomic_r_val_1  A_atomic_ie_2  ...  B_atomic_r_val_neg_1  \
# 0               1.11809      12.453816  ...               0.45805
# 1               1.11809      12.453816  ...               0.38335
# 2               1.11809      12.453816  ...               0.90925
# 3               1.11809      12.453816  ...               1.32395
# 4               1.11809      12.453816  ...               0.98135
# ...                 ...            ...  ...                   ...
# 35320           1.83315      11.030100  ...               1.20619
# 35321           1.83315      11.030100  ...               1.45087
# 35322           1.83315      11.030100  ...               1.33060
# 35323           1.83315      11.030100  ...               1.22782
# 35324           1.83315      11.030100  ...               1.10128
#
#        B_atomic_r_val  B_atomic_r_val_05  B_atomic_r_d_1  B_atomic_ie_2  \
# 0             0.44005            1.41305         0.44335      16.485700
# 1             0.38735            0.39065         0.38895      16.187700
# 2             0.85375            0.83435         0.82115      13.100000
# 3             1.18975            1.14245         0.26635      15.934610
# 4             0.90685            0.88435         0.86755      15.000000
# ...               ...                ...             ...            ...
# 35320         1.12409            1.64012         1.06461      11.525000
# 35321         1.19216            1.70297         0.00000      13.058342
# 35322         1.22489            1.73255         0.89817      12.375383
# 35323         1.14002            1.65512         1.07853      12.095000
# 35324         1.02539            1.54487         0.97458      11.667650
#
#        B_atomic_ndval  B_atomic_npval  B_atomic_nunf  B_atomic_nval  \
# 0                 5.0             0.0            6.0            6.0
# 1                 6.0             0.0            4.0            8.0
# 2                 2.0             0.0            8.0            4.0
# 3                10.0             2.0            4.0           14.0
# 4                 2.0             0.0            8.0           18.0
# ...               ...             ...            ...            ...
# 35320             1.3             0.0           17.8            4.0
# 35321             0.7             0.0           15.4            3.4
# 35322             3.7             0.6           16.6            7.0
# 35323             1.3             0.0           17.8            8.2
# 35324             1.3             0.0           17.8            4.0
#
#        B_atomic_phi
# 0             4.650
# 1             4.930
# 2             3.450
# 3             4.550
# 4             3.600
# ...             ...
# 35320         3.261
# 35321         3.741
# 35322         3.591
# 35323         3.306
# 35324         3.366
#
# [35325 rows x 29 columns]

# %%
X_GA = X.copy(deep = True)
X_GA['Eg'] = y
df = X_GA
df
# Out:
#        A_atomic_hpomo  A_atomic_lfumo  A_atomic_lpumo  A_atomic_ea  \
# 0           -2.165658       -2.165658       -2.165658    -0.299291
# 1           -2.165658       -2.165658       -2.165658    -0.299291
# 2           -2.165658       -2.165658       -2.165658    -0.299291
# 3           -2.165658       -2.165658       -2.165658    -0.299291
# 4           -2.165658       -2.165658       -2.165658    -0.299291
# ...               ...             ...             ...          ...
# 35320       -3.709160       -0.900650       -0.900650     1.114753
# 35321       -3.709160       -0.900650       -0.900650     1.114753
# 35322       -3.709160       -0.900650       -0.900650     1.114753
# 35323       -3.709160       -0.900650       -0.900650     1.114753
# 35324       -3.709160       -0.900650       -0.900650     1.114753
#
#        A_atomic_ip  A_atomic_r_val  A_atomic_r_s_1  A_atomic_r_d_1  \
# 0         4.230849         0.53737         0.00000             0.0
# 1         4.230849         0.53737         0.00000             0.0
# 2         4.230849         0.53737         0.00000             0.0
# 3         4.230849         0.53737         0.00000             0.0
# 4         4.230849         0.53737         0.00000             0.0
# ...            ...             ...             ...             ...
# 35320     5.960128         1.96785         1.83315             0.0
# 35321     5.960128         1.96785         1.83315             0.0
# 35322     5.960128         1.96785         1.83315             0.0
# 35323     5.960128         1.96785         1.83315             0.0
# 35324     5.960128         1.96785         1.83315             0.0
#
#        A_atomic_r_val_1  A_atomic_ie_2  ...  B_atomic_r_val  \
# 0               1.11809      12.453816  ...         0.44005
# 1               1.11809      12.453816  ...         0.38735
# 2               1.11809      12.453816  ...         0.85375
# 3               1.11809      12.453816  ...         1.18975
# 4               1.11809      12.453816  ...         0.90685
# ...                 ...            ...  ...             ...
# 35320           1.83315      11.030100  ...         1.12409
# 35321           1.83315      11.030100  ...         1.19216
# 35322           1.83315      11.030100  ...         1.22489
# 35323           1.83315      11.030100  ...         1.14002
# 35324           1.83315      11.030100  ...         1.02539
#
#        B_atomic_r_val_05  B_atomic_r_d_1  B_atomic_ie_2  B_atomic_ndval  \
# 0                1.41305         0.44335      16.485700             5.0
# 1                0.39065         0.38895      16.187700             6.0
# 2                0.83435         0.82115      13.100000             2.0
# 3                1.14245         0.26635      15.934610            10.0
# 4                0.88435         0.86755      15.000000             2.0
# ...                  ...             ...            ...             ...
# 35320            1.64012         1.06461      11.525000             1.3
# 35321            1.70297         0.00000      13.058342             0.7
# 35322            1.73255         0.89817      12.375383             3.7
# 35323            1.65512         1.07853      12.095000             1.3
# 35324            1.54487         0.97458      11.667650             1.3
#
#        B_atomic_npval  B_atomic_nunf  B_atomic_nval  B_atomic_phi        Eg
# 0                 0.0            6.0            6.0         4.650  2.146025
# 1                 0.0            4.0            8.0         4.930  1.374682
# 2                 0.0            8.0            4.0         3.450  4.177025
# 3                 2.0            4.0           14.0         4.550  3.941249
# 4                 0.0            8.0           18.0         3.600  4.529786
# ...               ...            ...            ...           ...       ...
# 35320             0.0           17.8            4.0         3.261  3.843865
# 35321             0.0           15.4            3.4         3.741  3.431016
# 35322             0.6           16.6            7.0         3.591  2.085930
# 35323             0.0           17.8            8.2         3.306  3.646532
# 35324             0.0           17.8            4.0         3.366  3.178124
#
# [35325 rows x 30 columns]

# %%
model = ExtraTreesRegressor(n_jobs=-1,random_state=42)
target = 'Eg'
feature_list = [i for i in df.columns if i not in target]
# Execute Genetic Algorithm to obtain Important Feature
from time import time
start = time()
feature_set, optimize_r2_score = ga(df, feature_list, target, 10, 500,model)
feature_set = [feature_list[j] for j in range(len(feature_list)) if feature_set[j]==1]
end = time()
print(f"运行时间T = %0.4f" % (end - start))
print('Optimal Feature Set\n',feature_set,'\nOptimal Accuracy =', round(optimize_r2_score*100), '%')
# Out:
# 第 0 次迭代T = 5.0956, optimize_value = 0.8428
# 第 1 次迭代T = 5.1676, optimize_value = 0.8480
# 第 2 次迭代T = 5.2075, optimize_value = 0.8480
# 第 3 次迭代T = 4.8140, optimize_value = 0.8480
# 第 4 次迭代T = 5.2874, optimize_value = 0.8480
# 第 5 次迭代T = 4.9485, optimize_value = 0.8480
# 第 6 次迭代T = 5.0961, optimize_value = 0.8480
# 第 7 次迭代T = 5.1377, optimize_value = 0.8480
# 第 8 次迭代T = 5.0380, optimize_value = 0.8480
# 第 9 次迭代T = 5.1359, optimize_value = 0.8480
# 第 10 次迭代T = 5.1511, optimize_value = 0.8480
# 第 11 次迭代T = 4.9505, optimize_value = 0.8480
# 第 12 次迭代T = 5.0746, optimize_value = 0.8480
# 第 13 次迭代T = 5.0838, optimize_value = 0.8480
# 第 14 次迭代T = 5.0548, optimize_value = 0.8480
# 第 15 次迭代T = 5.1286, optimize_value = 0.8480
# 第 16 次迭代T = 5.0971, optimize_value = 0.8480
# 第 17 次迭代T = 5.1366, optimize_value = 0.8480
# 第 18 次迭代T = 5.0977, optimize_value = 0.8480
# 第 19 次迭代T = 4.9005, optimize_value = 0.8480
# 第 20 次迭代T = 5.1217, optimize_value = 0.8480
# 第 21 次迭代T = 5.0222, optimize_value = 0.8480
# 第 22 次迭代T = 4.9342, optimize_value = 0.8480
# 第 23 次迭代T = 5.0793, optimize_value = 0.8480
# 第 24 次迭代T = 5.0046, optimize_value = 0.8480
# 第 25 次迭代T = 5.1388, optimize_value = 0.8480
# 第 26 次迭代T = 5.1384, optimize_value = 0.8480
# 第 27 次迭代T = 4.9158, optimize_value = 0.8480
# 第 28 次迭代T = 5.0606, optimize_value = 0.8480
# 第 29 次迭代T = 4.9139, optimize_value = 0.8480
# 第 30 次迭代T = 5.1548, optimize_value = 0.8480
# 第 31 次迭代T = 5.0962, optimize_value = 0.8480
# 第 32 次迭代T = 5.0314, optimize_value = 0.8480
# 第 33 次迭代T = 4.9519, optimize_value = 0.8480
# 第 34 次迭代T = 4.9908, optimize_value = 0.8480
# 第 35 次迭代T = 4.9922, optimize_value = 0.8480
# 第 36 次迭代T = 4.9700, optimize_value = 0.8480
# 第 37 次迭代T = 5.0382, optimize_value = 0.8480
# 第 38 次迭代T = 4.9347, optimize_value = 0.8480
# 第 39 次迭代T = 5.0449, optimize_value = 0.8480
# 第 40 次迭代T = 4.9595, optimize_value = 0.8480
# 第 41 次迭代T = 5.0469, optimize_value = 0.8480
# 第 42 次迭代T = 5.1043, optimize_value = 0.8480
# 第 43 次迭代T = 5.0294, optimize_value = 0.8480
# 第 44 次迭代T = 5.1893, optimize_value = 0.8480
# 第 45 次迭代T = 5.2606, optimize_value = 0.8480
# 第 46 次迭代T = 5.1427, optimize_value = 0.8480
# 第 47 次迭代T = 5.0715, optimize_value = 0.8480
# 第 48 次迭代T = 5.0721, optimize_value = 0.8480
# 第 49 次迭代T = 5.2271, optimize_value = 0.8480
# 第 50 次迭代T = 4.9686, optimize_value = 0.8480
# 第 51 次迭代T = 5.0967, optimize_value = 0.8480
# 第 52 次迭代T = 5.1696, optimize_value = 0.8480
# 第 53 次迭代T = 5.2360, optimize_value = 0.8480
# 第 54 次迭代T = 4.9679, optimize_value = 0.8480
# 第 55 次迭代T = 5.0874, optimize_value = 0.8480
# 第 56 次迭代T = 5.0189, optimize_value = 0.8480
# 第 57 次迭代T = 5.2911, optimize_value = 0.8480
# 第 58 次迭代T = 5.0789, optimize_value = 0.8480
# 第 59 次迭代T = 5.0672, optimize_value = 0.8480
# 第 60 次迭代T = 5.2592, optimize_value = 0.8480
# 第 61 次迭代T = 5.0636, optimize_value = 0.8480
# 第 62 次迭代T = 5.1000, optimize_value = 0.8480
# 第 63 次迭代T = 5.0983, optimize_value = 0.8480
# 第 64 次迭代T = 5.2269, optimize_value = 0.8480
# 第 65 次迭代T = 5.3267, optimize_value = 0.8480
# 第 66 次迭代T = 5.0068, optimize_value = 0.8480
# 第 67 次迭代T = 5.1261, optimize_value = 0.8480
# 第 68 次迭代T = 4.9349, optimize_value = 0.8480
# 第 69 次迭代T = 5.0386, optimize_value = 0.8480
# 第 70 次迭代T = 5.1097, optimize_value = 0.8480
# 第 71 次迭代T = 4.9653, optimize_value = 0.8480
# 第 72 次迭代T = 5.0735, optimize_value = 0.8480
# 第 73 次迭代T = 5.0443, optimize_value = 0.8480
# 第 74 次迭代T = 4.9867, optimize_value = 0.8480
# 第 75 次迭代T = 5.1036, optimize_value = 0.8480
# 第 76 次迭代T = 4.9502, optimize_value = 0.8480
# 第 77 次迭代T = 5.0721, optimize_value = 0.8480
# 第 78 次迭代T = 5.0191, optimize_value = 0.8480
# 第 79 次迭代T = 5.0344, optimize_value = 0.8480
# 第 80 次迭代T = 5.0189, optimize_value = 0.8480
# 第 81 次迭代T = 5.1072, optimize_value = 0.8480
# 第 82 次迭代T = 4.9680, optimize_value = 0.8480
# 第 83 次迭代T = 5.1998, optimize_value = 0.8480
# 第 84 次迭代T = 5.0048, optimize_value = 0.8480
# 第 85 次迭代T = 4.8692, optimize_value = 0.8480
# 第 86 次迭代T = 4.9230, optimize_value = 0.8480
# 第 87 次迭代T = 5.0979, optimize_value = 0.8480
# 第 88 次迭代T = 4.9893, optimize_value = 0.8480
# 第 89 次迭代T = 5.1058, optimize_value = 0.8480
# 第 90 次迭代T = 4.9669, optimize_value = 0.8480
# 第 91 次迭代T = 5.0339, optimize_value = 0.8480
# 第 92 次迭代T = 5.0274, optimize_value = 0.8480
# 第 93 次迭代T = 5.1658, optimize_value = 0.8480
# 第 94 次迭代T = 5.0729, optimize_value = 0.8480
# 第 95 次迭代T = 5.2340, optimize_value = 0.8480
# 第 96 次迭代T = 5.1070, optimize_value = 0.8480
# 第 97 次迭代T = 5.0171, optimize_value = 0.8480
# 第 98 次迭代T = 5.0919, optimize_value = 0.8480
# 第 99 次迭代T = 5.1832, optimize_value = 0.8480
# 第 100 次迭代T = 5.1920, optimize_value = 0.8480
# 第 101 次迭代T = 5.1695, optimize_value = 0.8480
# 第 102 次迭代T = 4.9986, optimize_value = 0.8480
# 第 103 次迭代T = 5.1381, optimize_value = 0.8480
# 第 104 次迭代T = 5.1027, optimize_value = 0.8480
# 第 105 次迭代T = 5.1291, optimize_value = 0.8480
# 第 106 次迭代T = 5.2038, optimize_value = 0.8480
# 第 107 次迭代T = 5.1214, optimize_value = 0.8480
# 第 108 次迭代T = 5.1187, optimize_value = 0.8480
# 第 109 次迭代T = 4.9993, optimize_value = 0.8480
# 第 110 次迭代T = 5.2307, optimize_value = 0.8480
# 第 111 次迭代T = 5.1480, optimize_value = 0.8480
# 第 112 次迭代T = 5.0682, optimize_value = 0.8480
# 第 113 次迭代T = 5.1503, optimize_value = 0.8481
# 第 114 次迭代T = 5.0463, optimize_value = 0.8481
# 第 115 次迭代T = 4.9589, optimize_value = 0.8481
# 第 116 次迭代T = 5.2250, optimize_value = 0.8481
# 第 117 次迭代T = 5.1902, optimize_value = 0.8481
# 第 118 次迭代T = 5.0555, optimize_value = 0.8481
# 第 119 次迭代T = 5.1401, optimize_value = 0.8481
# 第 120 次迭代T = 5.1808, optimize_value = 0.8481
# 第 121 次迭代T = 5.1489, optimize_value = 0.8481
# 第 122 次迭代T = 5.2367, optimize_value = 0.8481
# 第 123 次迭代T = 5.2581, optimize_value = 0.8481
# 第 124 次迭代T = 5.0630, optimize_value = 0.8481
# 第 125 次迭代T = 5.0627, optimize_value = 0.8481
# 第 126 次迭代T = 4.8904, optimize_value = 0.8481
# 第 127 次迭代T = 5.1732, optimize_value = 0.8481
# 第 128 次迭代T = 5.0549, optimize_value = 0.8481
# 第 129 次迭代T = 5.0771, optimize_value = 0.8481
# 第 130 次迭代T = 5.1741, optimize_value = 0.8481
# 第 131 次迭代T = 5.1581, optimize_value = 0.8481
# 第 132 次迭代T = 5.1772, optimize_value = 0.8481
# 第 133 次迭代T = 5.1579, optimize_value = 0.8481
# 第 134 次迭代T = 5.0870, optimize_value = 0.8481
# 第 135 次迭代T = 5.0693, optimize_value = 0.8481
# 第 136 次迭代T = 5.2237, optimize_value = 0.8481
# 第 137 次迭代T = 5.1323, optimize_value = 0.8481
# 第 138 次迭代T = 5.1451, optimize_value = 0.8481
# 第 139 次迭代T = 4.8896, optimize_value = 0.8481
# 第 140 次迭代T = 5.0111, optimize_value = 0.8481
# 第 141 次迭代T = 5.2333, optimize_value = 0.8481
# 第 142 次迭代T = 5.1600, optimize_value = 0.8481
# 第 143 次迭代T = 5.2000, optimize_value = 0.8481
# 第 144 次迭代T = 5.1820, optimize_value = 0.8481
# 第 145 次迭代T = 5.0056, optimize_value = 0.8481
# 第 146 次迭代T = 4.9662, optimize_value = 0.8481
# 第 147 次迭代T = 4.9211, optimize_value = 0.8481
# 第 148 次迭代T = 5.1765, optimize_value = 0.8481
# 第 149 次迭代T = 5.0245, optimize_value = 0.8481
# 第 150 次迭代T = 4.9469, optimize_value = 0.8481
# 第 151 次迭代T = 5.1163, optimize_value = 0.8481
# 第 152 次迭代T = 5.1202, optimize_value = 0.8481
# 第 153 次迭代T = 5.0664, optimize_value = 0.8481
# 第 154 次迭代T = 5.0687, optimize_value = 0.8481
# 第 155 次迭代T = 5.0174, optimize_value = 0.8481
# 第 156 次迭代T = 4.9540, optimize_value = 0.8481
# 第 157 次迭代T = 5.0365, optimize_value = 0.8481
# 第 158 次迭代T = 5.0887, optimize_value = 0.8481
# 第 159 次迭代T = 4.9134, optimize_value = 0.8481
# 第 160 次迭代T = 5.0060, optimize_value = 0.8481
# 第 161 次迭代T = 5.0527, optimize_value = 0.8481
# 第 162 次迭代T = 5.2856, optimize_value = 0.8481
# 第 163 次迭代T = 5.1542, optimize_value = 0.8481
# 第 164 次迭代T = 5.1106, optimize_value = 0.8481
# 第 165 次迭代T = 4.9187, optimize_value = 0.8481
# 第 166 次迭代T = 5.0226, optimize_value = 0.8481
# 第 167 次迭代T = 5.1685, optimize_value = 0.8481
# 第 168 次迭代T = 4.9982, optimize_value = 0.8519
# 第 169 次迭代T = 5.0365, optimize_value = 0.8519
# 第 170 次迭代T = 5.0625, optimize_value = 0.8519
# 第 171 次迭代T = 5.0292, optimize_value = 0.8519
# 第 172 次迭代T = 5.1291, optimize_value = 0.8519
# 第 173 次迭代T = 5.0246, optimize_value = 0.8519
# 第 174 次迭代T = 4.9640, optimize_value = 0.8519
# 第 175 次迭代T = 5.0368, optimize_value = 0.8519
# 第 176 次迭代T = 5.1709, optimize_value = 0.8519
# 第 177 次迭代T = 5.1625, optimize_value = 0.8519
# 第 178 次迭代T = 5.1052, optimize_value = 0.8519
# 第 179 次迭代T = 5.1371, optimize_value = 0.8519
# 第 180 次迭代T = 4.9939, optimize_value = 0.8519
# 第 181 次迭代T = 5.1741, optimize_value = 0.8519
# 第 182 次迭代T = 5.0848, optimize_value = 0.8519
# 第 183 次迭代T = 4.9522, optimize_value = 0.8519
# 第 184 次迭代T = 5.0928, optimize_value = 0.8519
# 第 185 次迭代T = 5.1478, optimize_value = 0.8519
# 第 186 次迭代T = 5.0517, optimize_value = 0.8519
# 第 187 次迭代T = 5.0931, optimize_value = 0.8519
# 第 188 次迭代T = 4.9068, optimize_value = 0.8519
# 第 189 次迭代T = 5.1595, optimize_value = 0.8519
# 第 190 次迭代T = 5.0847, optimize_value = 0.8519
# 第 191 次迭代T = 5.1060, optimize_value = 0.8519
# 第 192 次迭代T = 5.1389, optimize_value = 0.8519
# 第 193 次迭代T = 5.1081, optimize_value = 0.8519
# 第 194 次迭代T = 5.1287, optimize_value = 0.8519
# 第 195 次迭代T = 5.0141, optimize_value = 0.8519
# 第 196 次迭代T = 5.0702, optimize_value = 0.8519
# 第 197 次迭代T = 5.0242, optimize_value = 0.8519
# 第 198 次迭代T = 5.0650, optimize_value = 0.8519
# 第 199 次迭代T = 5.0783, optimize_value = 0.8519
# 第 200 次迭代T = 5.1126, optimize_value = 0.8519
# 第 201 次迭代T = 4.9500, optimize_value = 0.8519
# 第 202 次迭代T = 4.9812, optimize_value = 0.8519
# 第 203 次迭代T = 5.1841, optimize_value = 0.8519
# 第 204 次迭代T = 4.8534, optimize_value = 0.8519
# 第 205 次迭代T = 4.9808, optimize_value = 0.8519
# 第 206 次迭代T = 5.1990, optimize_value = 0.8519
# 第 207 次迭代T = 5.0511, optimize_value = 0.8519
# 第 208 次迭代T = 4.9627, optimize_value = 0.8519
# 第 209 次迭代T = 4.9531, optimize_value = 0.8519
# 第 210 次迭代T = 5.1963, optimize_value = 0.8519
# 第 211 次迭代T = 4.9078, optimize_value = 0.8519
# 第 212 次迭代T = 4.9896, optimize_value = 0.8519
# 第 213 次迭代T = 5.0966, optimize_value = 0.8519
# 第 214 次迭代T = 5.2494, optimize_value = 0.8519
# 第 215 次迭代T = 5.0570, optimize_value = 0.8519
# 第 216 次迭代T = 5.2844, optimize_value = 0.8519
# 第 217 次迭代T = 5.2084, optimize_value = 0.8519
# 第 218 次迭代T = 4.9474, optimize_value = 0.8519
# 第 219 次迭代T = 5.1581, optimize_value = 0.8519
# 第 220 次迭代T = 4.9840, optimize_value = 0.8519
# 第 221 次迭代T = 5.0481, optimize_value = 0.8519
# 第 222 次迭代T = 5.0875, optimize_value = 0.8519
# 第 223 次迭代T = 5.0600, optimize_value = 0.8519
# 第 224 次迭代T = 5.1227, optimize_value = 0.8519
# 第 225 次迭代T = 5.1121, optimize_value = 0.8519
# 第 226 次迭代T = 5.0677, optimize_value = 0.8519
# 第 227 次迭代T = 4.9179, optimize_value = 0.8519
# 第 228 次迭代T = 5.0854, optimize_value = 0.8519
# 第 229 次迭代T = 5.1163, optimize_value = 0.8519
# 第 230 次迭代T = 5.1298, optimize_value = 0.8519
# 第 231 次迭代T = 4.9351, optimize_value = 0.8519
# 第 232 次迭代T = 5.0391, optimize_value = 0.8519
# 第 233 次迭代T = 4.8808, optimize_value = 0.8519
# 第 234 次迭代T = 5.0859, optimize_value = 0.8519
# 第 235 次迭代T = 5.0378, optimize_value = 0.8519
# 第 236 次迭代T = 5.1241, optimize_value = 0.8519
# 第 237 次迭代T = 5.0685, optimize_value = 0.8519
# 第 238 次迭代T = 5.0760, optimize_value = 0.8519
# 第 239 次迭代T = 5.3011, optimize_value = 0.8519
# 第 240 次迭代T = 5.2144, optimize_value = 0.8519
# 第 241 次迭代T = 5.0038, optimize_value = 0.8519
# 第 242 次迭代T = 4.9567, optimize_value = 0.8519
# 第 243 次迭代T = 4.9973, optimize_value = 0.8519
# 第 244 次迭代T = 5.1300, optimize_value = 0.8519
# 第 245 次迭代T = 5.0277, optimize_value = 0.8519
# 第 246 次迭代T = 5.1227, optimize_value = 0.8519
# 第 247 次迭代T = 5.0728, optimize_value = 0.8519
# 第 248 次迭代T = 4.9086, optimize_value = 0.8519
# 第 249 次迭代T = 5.0228, optimize_value = 0.8519
# 第 250 次迭代T = 4.9279, optimize_value = 0.8519
# 第 251 次迭代T = 4.9643, optimize_value = 0.8519
# 第 252 次迭代T = 4.9345, optimize_value = 0.8519
# 第 253 次迭代T = 4.9855, optimize_value = 0.8519
# 第 254 次迭代T = 4.9630, optimize_value = 0.8519
# 第 255 次迭代T = 5.1448, optimize_value = 0.8519
# 第 256 次迭代T = 5.1322, optimize_value = 0.8519
# 第 257 次迭代T = 5.0647, optimize_value = 0.8519
# 第 258 次迭代T = 5.0971, optimize_value = 0.8519
# 第 259 次迭代T = 5.0211, optimize_value = 0.8519
# 第 260 次迭代T = 5.0291, optimize_value = 0.8519
# 第 261 次迭代T = 5.0733, optimize_value = 0.8519
# 第 262 次迭代T = 5.0454, optimize_value = 0.8519
# 第 263 次迭代T = 5.3205, optimize_value = 0.8519
# 第 264 次迭代T = 5.3485, optimize_value = 0.8519
# 第 265 次迭代T = 5.1586, optimize_value = 0.8519
# 第 266 次迭代T = 5.1980, optimize_value = 0.8519
# 第 267 次迭代T = 5.1839, optimize_value = 0.8519
# 第 268 次迭代T = 5.0792, optimize_value = 0.8519
# 第 269 次迭代T = 5.0401, optimize_value = 0.8519
# 第 270 次迭代T = 4.9838, optimize_value = 0.8519
# 第 271 次迭代T = 5.0582, optimize_value = 0.8519
# 第 272 次迭代T = 5.1315, optimize_value = 0.8519
# 第 273 次迭代T = 5.0493, optimize_value = 0.8519
# 第 274 次迭代T = 5.0310, optimize_value = 0.8519
# 第 275 次迭代T = 4.9832, optimize_value = 0.8519
# 第 276 次迭代T = 4.9291, optimize_value = 0.8519
# 第 277 次迭代T = 5.1196, optimize_value = 0.8519
# 第 278 次迭代T = 4.9850, optimize_value = 0.8519
# 第 279 次迭代T = 5.0650, optimize_value = 0.8519
# 第 280 次迭代T = 5.2494, optimize_value = 0.8519
# 第 281 次迭代T = 5.1844, optimize_value = 0.8519
# 第 282 次迭代T = 5.0295, optimize_value = 0.8519
# 第 283 次迭代T = 5.0871, optimize_value = 0.8519
# 第 284 次迭代T = 5.0854, optimize_value = 0.8519
# 第 285 次迭代T = 5.0446, optimize_value = 0.8519
# 第 286 次迭代T = 4.9796, optimize_value = 0.8519
# 第 287 次迭代T = 5.0496, optimize_value = 0.8519
# 第 288 次迭代T = 5.0831, optimize_value = 0.8519
# 第 289 次迭代T = 5.0881, optimize_value = 0.8519
# 第 290 次迭代T = 5.1439, optimize_value = 0.8519
# 第 291 次迭代T = 5.0823, optimize_value = 0.8519
# 第 292 次迭代T = 5.1318, optimize_value = 0.8519
# 第 293 次迭代T = 5.0047, optimize_value = 0.8519
# 第 294 次迭代T = 5.2039, optimize_value = 0.8519
# 第 295 次迭代T = 5.1754, optimize_value = 0.8519
# 第 296 次迭代T = 5.1179, optimize_value = 0.8519
# 第 297 次迭代T = 4.9908, optimize_value = 0.8519
# 第 298 次迭代T = 5.1281, optimize_value = 0.8519
# 第 299 次迭代T = 5.1413, optimize_value = 0.8519
# 第 300 次迭代T = 5.0855, optimize_value = 0.8519
# 第 301 次迭代T = 5.2093, optimize_value = 0.8519
# 第 302 次迭代T = 4.9435, optimize_value = 0.8519
# 第 303 次迭代T = 5.0502, optimize_value = 0.8519
# 第 304 次迭代T = 4.9677, optimize_value = 0.8519
# 第 305 次迭代T = 5.0342, optimize_value = 0.8519
# 第 306 次迭代T = 5.0643, optimize_value = 0.8519
# 第 307 次迭代T = 5.0553, optimize_value = 0.8519
# 第 308 次迭代T = 5.2306, optimize_value = 0.8519
# 第 309 次迭代T = 5.0290, optimize_value = 0.8519
# 第 310 次迭代T = 4.8748, optimize_value = 0.8519
# 第 311 次迭代T = 5.1480, optimize_value = 0.8519
# 第 312 次迭代T = 5.0513, optimize_value = 0.8519
# 第 313 次迭代T = 5.0804, optimize_value = 0.8519
# 第 314 次迭代T = 5.0806, optimize_value = 0.8519
# 第 315 次迭代T = 5.1788, optimize_value = 0.8519
# 第 316 次迭代T = 4.9748, optimize_value = 0.8519
# 第 317 次迭代T = 5.0530, optimize_value = 0.8519
# 第 318 次迭代T = 4.9372, optimize_value = 0.8519
# 第 319 次迭代T = 4.9741, optimize_value = 0.8519
# 第 320 次迭代T = 5.2998, optimize_value = 0.8519
# 第 321 次迭代T = 5.2833, optimize_value = 0.8519
# 第 322 次迭代T = 5.3752, optimize_value = 0.8519
# 第 323 次迭代T = 5.0213, optimize_value = 0.8519
# 第 324 次迭代T = 5.2388, optimize_value = 0.8519
# 第 325 次迭代T = 5.1016, optimize_value = 0.8519
# 第 326 次迭代T = 5.0866, optimize_value = 0.8519
# 第 327 次迭代T = 5.1908, optimize_value = 0.8519
# 第 328 次迭代T = 5.2238, optimize_value = 0.8519
# 第 329 次迭代T = 5.0620, optimize_value = 0.8519
# 第 330 次迭代T = 5.0477, optimize_value = 0.8519
# 第 331 次迭代T = 5.0486, optimize_value = 0.8519
# 第 332 次迭代T = 5.0091, optimize_value = 0.8519
# 第 333 次迭代T = 5.0357, optimize_value = 0.8519
# 第 334 次迭代T = 5.1479, optimize_value = 0.8519
# 第 335 次迭代T = 5.0718, optimize_value = 0.8519
# 第 336 次迭代T = 5.1025, optimize_value = 0.8519
# 第 337 次迭代T = 4.9737, optimize_value = 0.8519
# 第 338 次迭代T = 5.0988, optimize_value = 0.8519
# 第 339 次迭代T = 5.0969, optimize_value = 0.8519
# 第 340 次迭代T = 4.8413, optimize_value = 0.8519
# 第 341 次迭代T = 4.9615, optimize_value = 0.8519
# 第 342 次迭代T = 4.8341, optimize_value = 0.8519
# 第 343 次迭代T = 5.0746, optimize_value = 0.8519
# 第 344 次迭代T = 5.1886, optimize_value = 0.8519
# 第 345 次迭代T = 4.9618, optimize_value = 0.8519
# 第 346 次迭代T = 5.2376, optimize_value = 0.8519
# 第 347 次迭代T = 5.2038, optimize_value = 0.8519
# 第 348 次迭代T = 5.0310, optimize_value = 0.8519
# 第 349 次迭代T = 5.0080, optimize_value = 0.8519
# 第 350 次迭代T = 5.3112, optimize_value = 0.8519
# 第 351 次迭代T = 5.2949, optimize_value = 0.8519
# 第 352 次迭代T = 4.8841, optimize_value = 0.8519
# 第 353 次迭代T = 5.3544, optimize_value = 0.8519
# 第 354 次迭代T = 5.2405, optimize_value = 0.8519
# 第 355 次迭代T = 5.2122, optimize_value = 0.8519
# 第 356 次迭代T = 5.2211, optimize_value = 0.8519
# 第 357 次迭代T = 4.8839, optimize_value = 0.8519
# 第 358 次迭代T = 4.9246, optimize_value = 0.8519
# 第 359 次迭代T = 4.8469, optimize_value = 0.8519
# 第 360 次迭代T = 4.8903, optimize_value = 0.8519
# 第 361 次迭代T = 5.3934, optimize_value = 0.8519
# 第 362 次迭代T = 4.8045, optimize_value = 0.8519
# 第 363 次迭代T = 4.9593, optimize_value = 0.8519
# 第 364 次迭代T = 4.9621, optimize_value = 0.8519
# 第 365 次迭代T = 5.1188, optimize_value = 0.8519
# 第 366 次迭代T = 5.1110, optimize_value = 0.8519
# 第 367 次迭代T = 4.9736, optimize_value = 0.8519
# 第 368 次迭代T = 4.9647, optimize_value = 0.8519
# 第 369 次迭代T = 5.0584, optimize_value = 0.8519
# 第 370 次迭代T = 5.0039, optimize_value = 0.8519
# 第 371 次迭代T = 5.1231, optimize_value = 0.8519
# 第 372 次迭代T = 5.1152, optimize_value = 0.8519
# 第 373 次迭代T = 5.2064, optimize_value = 0.8519
# 第 374 次迭代T = 5.0137, optimize_value = 0.8519
# 第 375 次迭代T = 5.1428, optimize_value = 0.8519
# 第 376 次迭代T = 4.9676, optimize_value = 0.8519
# 第 377 次迭代T = 5.0926, optimize_value = 0.8519
# 第 378 次迭代T = 5.1244, optimize_value = 0.8519
# 第 379 次迭代T = 5.1416, optimize_value = 0.8519
# 第 380 次迭代T = 5.1316, optimize_value = 0.8519
# 第 381 次迭代T = 5.1201, optimize_value = 0.8519
# 第 382 次迭代T = 4.9993, optimize_value = 0.8519
# 第 383 次迭代T = 4.9200, optimize_value = 0.8519
# 第 384 次迭代T = 4.9731, optimize_value = 0.8519
# 第 385 次迭代T = 4.9706, optimize_value = 0.8519
# 第 386 次迭代T = 4.8192, optimize_value = 0.8519
# 第 387 次迭代T = 5.0303, optimize_value = 0.8519
# 第 388 次迭代T = 5.0219, optimize_value = 0.8519
# 第 389 次迭代T = 5.1872, optimize_value = 0.8519
# 第 390 次迭代T = 5.1450, optimize_value = 0.8519
# 第 391 次迭代T = 5.2118, optimize_value = 0.8519
# 第 392 次迭代T = 5.0389, optimize_value = 0.8519
# 第 393 次迭代T = 4.9103, optimize_value = 0.8519
# 第 394 次迭代T = 4.9022, optimize_value = 0.8519
# 第 395 次迭代T = 4.7436, optimize_value = 0.8519
# 第 396 次迭代T = 4.8624, optimize_value = 0.8519
# 第 397 次迭代T = 4.9573, optimize_value = 0.8519
# 第 398 次迭代T = 5.1761, optimize_value = 0.8519
# 第 399 次迭代T = 5.0267, optimize_value = 0.8519
# 第 400 次迭代T = 5.1583, optimize_value = 0.8519
# 第 401 次迭代T = 4.9920, optimize_value = 0.8519
# 第 402 次迭代T = 5.1884, optimize_value = 0.8519
# 第 403 次迭代T = 5.4610, optimize_value = 0.8519
# 第 404 次迭代T = 4.9652, optimize_value = 0.8519
# 第 405 次迭代T = 5.0895, optimize_value = 0.8519
# 第 406 次迭代T = 4.9620, optimize_value = 0.8519
# 第 407 次迭代T = 4.9574, optimize_value = 0.8519
# 第 408 次迭代T = 4.9455, optimize_value = 0.8519
# 第 409 次迭代T = 5.1597, optimize_value = 0.8519
# 第 410 次迭代T = 5.2703, optimize_value = 0.8519
# 第 411 次迭代T = 5.2494, optimize_value = 0.8519
# 第 412 次迭代T = 5.2505, optimize_value = 0.8519
# 第 413 次迭代T = 5.2313, optimize_value = 0.8519
# 第 414 次迭代T = 4.9955, optimize_value = 0.8519
# 第 415 次迭代T = 5.0481, optimize_value = 0.8519
# 第 416 次迭代T = 5.1916, optimize_value = 0.8519
# 第 417 次迭代T = 5.0615, optimize_value = 0.8519
# 第 418 次迭代T = 5.0477, optimize_value = 0.8519
# 第 419 次迭代T = 5.3480, optimize_value = 0.8519
# 第 420 次迭代T = 5.3052, optimize_value = 0.8519
# 第 421 次迭代T = 5.0785, optimize_value = 0.8519
# 第 422 次迭代T = 5.0236, optimize_value = 0.8519
# 第 423 次迭代T = 5.0266, optimize_value = 0.8519
# 第 424 次迭代T = 5.1599, optimize_value = 0.8519
# 第 425 次迭代T = 5.0938, optimize_value = 0.8519
# 第 426 次迭代T = 5.1848, optimize_value = 0.8519
# 第 427 次迭代T = 5.0873, optimize_value = 0.8519
# 第 428 次迭代T = 5.0932, optimize_value = 0.8519
# 第 429 次迭代T = 5.0429, optimize_value = 0.8519
# 第 430 次迭代T = 5.0161, optimize_value = 0.8519
# 第 431 次迭代T = 5.3388, optimize_value = 0.8519
# 第 432 次迭代T = 5.1451, optimize_value = 0.8519
# 第 433 次迭代T = 5.2035, optimize_value = 0.8519
# 第 434 次迭代T = 5.2694, optimize_value = 0.8519
# 第 435 次迭代T = 5.2468, optimize_value = 0.8519
# 第 436 次迭代T = 5.0633, optimize_value = 0.8519
# 第 437 次迭代T = 5.1350, optimize_value = 0.8519
# 第 438 次迭代T = 4.9972, optimize_value = 0.8519
# 第 439 次迭代T = 5.1736, optimize_value = 0.8519
# 第 440 次迭代T = 5.0432, optimize_value = 0.8519
# 第 441 次迭代T = 5.0664, optimize_value = 0.8519
# 第 442 次迭代T = 5.1842, optimize_value = 0.8519
# 第 443 次迭代T = 5.0771, optimize_value = 0.8519
# 第 444 次迭代T = 5.0276, optimize_value = 0.8519
# 第 445 次迭代T = 4.9432, optimize_value = 0.8519
# 第 446 次迭代T = 5.0594, optimize_value = 0.8519
# 第 447 次迭代T = 5.1777, optimize_value = 0.8519
# 第 448 次迭代T = 4.9322, optimize_value = 0.8519
# 第 449 次迭代T = 5.2416, optimize_value = 0.8519
# 第 450 次迭代T = 4.9537, optimize_value = 0.8519
# 第 451 次迭代T = 5.2154, optimize_value = 0.8519
# 第 452 次迭代T = 4.9462, optimize_value = 0.8519
# 第 453 次迭代T = 5.1800, optimize_value = 0.8519
# 第 454 次迭代T = 5.0715, optimize_value = 0.8519
# 第 455 次迭代T = 4.9584, optimize_value = 0.8519
# 第 456 次迭代T = 4.9843, optimize_value = 0.8519
# 第 457 次迭代T = 4.9833, optimize_value = 0.8519
# 第 458 次迭代T = 5.0073, optimize_value = 0.8519
# 第 459 次迭代T = 5.1579, optimize_value = 0.8519
# 第 460 次迭代T = 5.2324, optimize_value = 0.8519
# 第 461 次迭代T = 4.9541, optimize_value = 0.8519
# 第 462 次迭代T = 4.8846, optimize_value = 0.8519
# 第 463 次迭代T = 5.0603, optimize_value = 0.8519
# 第 464 次迭代T = 5.0340, optimize_value = 0.8519
# 第 465 次迭代T = 5.0671, optimize_value = 0.8519
# 第 466 次迭代T = 5.0593, optimize_value = 0.8519
# 第 467 次迭代T = 4.9890, optimize_value = 0.8519
# 第 468 次迭代T = 5.1415, optimize_value = 0.8519
# 第 469 次迭代T = 5.0039, optimize_value = 0.8519
# 第 470 次迭代T = 4.8995, optimize_value = 0.8519
# 第 471 次迭代T = 5.1354, optimize_value = 0.8519
# 第 472 次迭代T = 4.9925, optimize_value = 0.8519
# 第 473 次迭代T = 4.9675, optimize_value = 0.8519
# 第 474 次迭代T = 4.9759, optimize_value = 0.8519
# 第 475 次迭代T = 5.1643, optimize_value = 0.8519
# 第 476 次迭代T = 5.0292, optimize_value = 0.8519
# 第 477 次迭代T = 5.1197, optimize_value = 0.8519
# 第 478 次迭代T = 4.9348, optimize_value = 0.8519
# 第 479 次迭代T = 5.1960, optimize_value = 0.8519
# 第 480 次迭代T = 5.0762, optimize_value = 0.8519
# 第 481 次迭代T = 5.2348, optimize_value = 0.8519
# 第 482 次迭代T = 5.1912, optimize_value = 0.8519
# 第 483 次迭代T = 5.1818, optimize_value = 0.8519
# 第 484 次迭代T = 5.1536, optimize_value = 0.8519
# 第 485 次迭代T = 5.0097, optimize_value = 0.8519
# 第 486 次迭代T = 5.0695, optimize_value = 0.8519
# 第 487 次迭代T = 4.9742, optimize_value = 0.8519
# 第 488 次迭代T = 4.9758, optimize_value = 0.8519
# 第 489 次迭代T = 5.2213, optimize_value = 0.8519
# 第 490 次迭代T = 5.2306, optimize_value = 0.8519
# 第 491 次迭代T = 5.1764, optimize_value = 0.8519
# 第 492 次迭代T = 5.1011, optimize_value = 0.8519
# 第 493 次迭代T = 5.0483, optimize_value = 0.8519
# 第 494 次迭代T = 4.9006, optimize_value = 0.8519
# 第 495 次迭代T = 5.1153, optimize_value = 0.8519
# 第 496 次迭代T = 5.0887, optimize_value = 0.8519
# 第 497 次迭代T = 5.0054, optimize_value = 0.8519
# 第 498 次迭代T = 5.0951, optimize_value = 0.8519
# 第 499 次迭代T = 5.1152, optimize_value = 0.8519
# 运行时间T = 2544.2313
# Optimal Feature Set
#  ['A_atomic_hpomo', 'A_atomic_lfumo', 'A_atomic_ea', 'A_atomic_r_val', 'A_atomic_r_s_1', 'A_atomic_r_d_1', 'A_atomic_r_val_1', 'A_atomic_ie_2', 'A_atomic_ndval', 'A_atomic_nfunf', 'A_atomic_nunf', 'A_atomic_nval', 'B_atomic_hfomo', 'B_atomic_lpumo', 'B_atomic_ip_by_half_charged_homo', 'B_atomic_r_val', 'B_atomic_r_val_05', 'B_atomic_r_d_1', 'B_atomic_ndval', 'B_atomic_npval', 'B_atomic_nunf', 'B_atomic_phi']
# Optimal Accuracy = 85 %

# %%
small_features = ABO3_atomic_features[select_atomic_labels]
small_features
# Out:
#     A_atomic_hfomo  A_atomic_hpomo  A_atomic_lfumo  A_atomic_lpumo  \
# 0         -3.50498        -1.78977        -1.78977        -1.78977
# 1         -4.38669        -2.25963        -2.25963        -2.25963
# 2         -2.01997        -2.01997        -0.47011        -0.47011
# 3         -4.19464        -1.78655        -1.78655        -1.78655
# 4         -3.59121        -2.34754        -2.34754        -2.34754
# 5         -3.50498        -1.78977        -1.78977        -1.78977
# 6         -4.19464        -1.78655        -1.78655        -1.78655
# 7         -3.59121        -2.34754        -2.34754        -2.34754
# 8         -3.55283        -1.85729        -1.85729        -1.85729
# 9         -2.78148        -2.78148        -1.07232        -1.07232
# 10        -4.19464        -1.78655        -1.78655        -1.78655
# 11        -3.68633        -3.68754         0.25454        -3.68754
# 12        -3.50498        -1.78977        -1.78977        -1.78977
# 13        -2.78148        -2.78148        -1.07232        -1.07232
# 14        -2.12349        -2.12349        -2.12349        -2.12349
# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from tqdm import tqdm
train_model = ExtraTreesRegressor(n_jobs=-1,random_state=42)
error1 = []
error2 = []
r2_prm = []
error1_base=[]
error2_base=[]
r2_prl=[]
train_set = []
test_set = []
tmp_df = pd.DataFrame()
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_indices = kf.split(X,y)
small_features = small_features[feature_set]
for i,(train_index, test_index) in enumerate(cv_indices):
    train_set.append(train_index)
    test_set.append(test_index)
    X_train, X_test = X.loc[train_index], X.loc[test_index]
    y_train, y_test = y.loc[train_index], y.loc[test_index]
    X_train = X_train[feature_set]
    X_test = X_test[feature_set]
    name = f"fold_{i}"
    train_model.fit(X_train, y_train)
    
    y_pred = train_model.predict(X_test)
    mae_model = mean_absolute_error(y_test, y_pred)
    rmse_model = np.sqrt(mean_squared_error(y_test, y_pred))
    r2_model = r2_score(y_test,y_pred)
    error1.append(mae_model)
    error2.append(rmse_model)
    r2_prm.append(r2_model)
    
    y_base_4 = train_model.predict(small_features)
    tmp_df[f'column_{i}'] = y_base_4
    MAE_BASE_4 = mean_absolute_error(y_base_4,y_eg_abo3)
    RMSE_BASE_4 = np.sqrt(mean_squared_error(y_base_4,y_eg_abo3))
    R2_BASE_4 = r2_score(y_base_4,y_eg_abo3)
    error1_base.append(MAE_BASE_4)
    error2_base.append(RMSE_BASE_4)
    r2_prl.append(R2_BASE_4)
    print(name)
    print(f"Performance on the test set: MAE = %0.4f,RMSE = %0.4f, R2 = %0.4f" % (mae_model, rmse_model, r2_model))
    print(f"Performance on the small set: MAE = %0.4f,RMSE = %0.4f, R2 = %0.4f" % (MAE_BASE_4, RMSE_BASE_4, R2_BASE_4))
mean_error1 = sum(error1) / len(error1)
mean_error2 = sum(error2) / len(error2)
mean_r2 = sum(r2_prm) / len(r2_prm)
print('Performance on the test set using 5-fold: MAE = %0.4f' % mean_error1)
print('Performance on the test set using 5-fold: RMSE = %0.4f' % mean_error2)
print('Performance on the test set using 5-fold: R2 = %0.4f' % mean_r2)

mean_error1_base = sum(error1_base) / len(error1_base)
mean_error2_base = sum(error2_base) / len(error2_base)
mean_r2_base = sum(r2_prl) / len(r2_prl)
print('Performance on the valid set using 5-fold: MAE = %0.4f' % mean_error1_base)
print('Performance on the valid set using 5-fold: RMSE = %0.4f' % mean_error2_base)
print('Performance on the valid set using 5-fold: R2 = %0.4f' % mean_r2_base)
# Out:
# fold_0
# Performance on the test set: MAE = 0.3507,RMSE = 0.4779, R2 = 0.8511
# Performance on the small set: MAE = 0.3914,RMSE = 0.5180, R2 = 0.6475
# fold_1
# Performance on the test set: MAE = 0.3547,RMSE = 0.4853, R2 = 0.8453
# Performance on the small set: MAE = 0.3868,RMSE = 0.4928, R2 = 0.7014
# fold_2
# Performance on the test set: MAE = 0.3548,RMSE = 0.4855, R2 = 0.8503
# Performance on the small set: MAE = 0.4091,RMSE = 0.5415, R2 = 0.6390
# fold_3
# Performance on the test set: MAE = 0.3483,RMSE = 0.4784, R2 = 0.8488
# Performance on the small set: MAE = 0.4050,RMSE = 0.5308, R2 = 0.6532
# fold_4
# Performance on the test set: MAE = 0.3464,RMSE = 0.4753, R2 = 0.8515
# Performance on the small set: MAE = 0.3895,RMSE = 0.5013, R2 = 0.6851
# Performance on the test set using 5-fold: MAE = 0.3510
# Performance on the test set using 5-fold: RMSE = 0.4805
# Performance on the test set using 5-fold: R2 = 0.8494
# Performance on the valid set using 5-fold: MAE = 0.3964
# Performance on the valid set using 5-fold: RMSE = 0.5169
# Performance on the valid set using 5-fold: R2 = 0.6652

# %%
best_train_index = train_set[4]
best_test_index = test_set[4]
best_X_train = X.loc[best_train_index].reset_index(drop=True)
best_X_test = X.loc[best_test_index].reset_index(drop=True)
best_y_train = y.loc[best_train_index].reset_index(drop=True)
best_y_test = y.loc[best_test_index].reset_index(drop=True)

# %%
best_X_train = best_X_train[feature_set]
best_X_test = best_X_test[feature_set]

# %%
model = ExtraTreesRegressor(n_jobs=-1, random_state=42)
model.fit(best_X_train, best_y_train)
y_pred = model.predict(best_X_test)
MAE_4 = mean_absolute_error(best_y_test,y_pred)
RMSE_4 = np.sqrt(mean_squared_error(best_y_test, y_pred))
R2_4 = r2_score(best_y_test,y_pred)
print('Performance on the test set: MAE = %0.4f' % MAE_4)
print('Performance on the test set: RMSE = %0.4f' % RMSE_4)
print('Performance on the test set: R2 SCORE = %0.4f' % R2_4)
# Out:
# Performance on the test set: MAE = 0.3464
# Performance on the test set: RMSE = 0.4753
# Performance on the test set: R2 SCORE = 0.8515

# %%
# import json
# with open("best_feature_ec.json", "w") as f:
#     json.dump(feature_set, f)

# %%
# import pickle
# with open('model_ec.pkl', 'wb') as f:
#     pickle.dump(model, f)

# %%
error_data = pd.DataFrame(columns = ['formula','valid_Eg','pred_Eg'])
error_data['formula'] = small_data['formula']
error_data['valid_Eg'] = small_data['target']
error_data['pred_Eg'] = tmp_df['column_4']
error_data['diff'] = abs(error_data['valid_Eg'] - error_data['pred_Eg'])
error_data = error_data.sort_values(by='diff', ascending=False).reset_index(drop = True)
error_data
# Out:
#    formula  valid_Eg   pred_Eg      diff
# 0   BaCeO3  3.941353  2.622542  1.318811
# 1   TaAgO3  3.135210  2.150132  0.985078
# 2   TiPbO3  2.584444  1.679295  0.905149
# 3   DyInO3  2.996601  3.884960  0.888358
# 4   ZrPbO3  3.477219  2.598152  0.879067
# 5   NbAgO3  2.606289  1.735743  0.870546
# 6   InBiO3  1.050888  1.886769  0.835881
# 7   HfPbO3  3.538460  2.738099  0.800361
# 8   InSbO3  0.751440  1.537170  0.785730
# 9   PmInO3  3.056738  3.730180  0.673441
# 10  NdInO3  2.999078  3.609956  0.610877
# 11  GaBiO3  2.249296  2.851148  0.601853
# 12  RbNbO3  2.697864  2.097555  0.600309
# 13  CeBeO3  2.439456  1.867079  0.572377
# 14  GdAlO3  3.423982  3.982159  0.558177
# 15  EuHfO3  1.513985  0.960861  0.553124
# 16  LaCrO3  1.903900  1.356912  0.546988
# 17  CdSnO3  1.230115  1.768132  0.538017
# 18   KTaO3  3.328060  2.806267  0.521793
# 19   YCrO3  1.767900  1.289950  0.477950
# 20  PmErO3  3.361074  3.817777  0.456702
# 21  YbGeO3  2.036664  2.460491  0.423827
# 22  EuZrO3  1.348938  0.942302  0.406636
# 23  GdCrO3  0.825000  1.231392  0.406392
# 24  CdGeO3  1.748022  2.139858  0.391836
# 25  SmFeO3  0.723500  1.114927  0.391427
# 26  NaNbO3  2.833721  2.457657  0.376064
# 27   YFeO3  0.637300  0.966812  0.329512
# 28  NdCrO3  1.904000  1.581841  0.322159
# 29  TmCrO3  1.928900  2.134015  0.205115
# 30  NbTlO3  1.074396  1.261042  0.186646
# 31  SmCoO3  0.803900  0.618314  0.185586
# 32  PrCrO3  1.847000  1.675574  0.171426
# 33  MgTiO3  3.194852  3.353214  0.158362
# 34  TaTlO3  1.757035  1.602354  0.154681
# 35  BaSnO3  1.883683  2.032571  0.148888
# 36  CaTiO3  3.207814  3.077753  0.130061
# 37  CsTaO3  3.110664  2.996392  0.114272
# 38  TiSnO3  1.899045  1.799450  0.099595
# 39  CsNbO3  2.453558  2.358636  0.094922
# 40  RbTaO3  3.238719  3.157610  0.081108
# 41  SnPbO3  2.035434  1.958886  0.076548
# 42  HfBeO3  2.544336  2.473636  0.070700
# 43  SrSnO3  2.577727  2.510199  0.067528
# 44  LaFeO3  0.848400  0.913756  0.065356
# 45  BaTiO3  2.868957  2.807053  0.061904
# 46  SrTiO3  3.094581  3.035759  0.058822
# 47   YCoO3  0.833000  0.791697  0.041303
# 48  NdCoO3  0.791400  0.772964  0.018436
# 49  ScCoO3  0.786000  0.767701  0.018299
# 50  SmCrO3  1.736200  1.722415  0.013785
# 51   KNbO3  2.591651  2.590866  0.000786

# %%
# error_data.to_csv('EC_errror.csv')

# %%
train_data = X[feature_set]
predict_y = model.predict(train_data)

# %%
large_error_data = pd.DataFrame(columns = ['valid_Eg','pred_Eg'])
large_error_data['valid_Eg'] = y
large_error_data['pred_Eg'] = predict_y
large_error_data['diff'] = abs(large_error_data['valid_Eg'] - large_error_data['pred_Eg'])
large_error_data = large_error_data.sort_values(by='diff', ascending=False).reset_index(drop = True)
large_error_data
# Out:
#        valid_Eg   pred_Eg      diff
# 0      1.357424  5.538459  4.181036
# 1      0.963888  4.652260  3.688372
# 2      1.091527  4.770885  3.679358
# 3      1.230096  4.278437  3.048341
# 4      1.329234  4.238745  2.909511
# ...         ...       ...       ...
# 35320  4.528787  4.528787  0.000000
# 35321  2.312129  2.312129  0.000000
# 35322  1.844291  1.844291  0.000000
# 35323  1.277718  1.277718  0.000000
# 35324  3.178124  3.178124  0.000000
#
# [35325 rows x 3 columns]

# %%
large_error_data.to_csv('large_ec_error.csv')

# %%
ec_error_big = pd.DataFrame(columns = ['Eg_error'])
ec_error_big['Eg_error'] = abs(best_y_test-y_pred)
ec_error_big
# Out:
#       Eg_error
# 0     0.090501
# 1     0.000400
# 2     0.035522
# 3     0.017994
# 4     0.430191
# ...        ...
# 7060  0.024589
# 7061  0.023237
# 7062  0.049489
# 7063  0.214915
# 7064  0.009624
#
# [7065 rows x 1 columns]

# %%
# ec_error_big.to_csv('ec_error_big.csv')
